# %%
# !pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\jnoot\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\jnoot\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles']}

pd.DataFrame(data)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
df=pd.read_csv(r"F:\Data Science\Kaggle Data Sets\realtor_data_for_ml.csv")
df
# Out:
#              n    status  bed  bath  acre_lot           city          state  \
# 0            0  for_sale  8.0     4      0.06       Brooklyn       New York
# 1            1  for_sale  3.0     2      0.09  Campbell Hall       New York
# 2            2  for_sale  3.0     3      0.11      Hopkinton  Massachusetts
# 3            3  for_sale  6.0     8      4.00     New Canaan    Connecticut
# 4            4  for_sale  8.0     3      0.02          Bronx       New York
# ...        ...       ...  ...   ...       ...            ...            ...
# 677137  677137  for_sale  2.0     2     20.00      Cazenovia       New York
# 677138  677138  for_sale  4.0     3     33.00       Woodbury    Connecticut
# 677139  677139  for_sale  3.0     1      0.21      Millville     New Jersey
# 677140  677140  for_sale  3.0     3      1.80          Keene  New Hampshire
# 677141  677141  for_sale  4.0     3      0.14         Elmont       New York
#
#         house_size    price         timestamp
# ...

# %%
df.columns
# Out:
# Index(['n', 'status', 'bed', 'bath', 'acre_lot', 'city', 'state', 'house_size',
#        'price', 'timestamp'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    n    status  bed  bath  acre_lot           city          state  house_size  \
# 0  0  for_sale  8.0     4      0.06       Brooklyn       New York        3198
# 1  1  for_sale  3.0     2      0.09  Campbell Hall       New York        1482
# 2  2  for_sale  3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3  3  for_sale  6.0     8      4.00     New Canaan    Connecticut        9385
# 4  4  for_sale  8.0     3      0.02          Bronx       New York        2565
# 5  5  for_sale  3.0     2      1.08         Granby  Massachusetts        1463
# 6  6  for_sale  4.0     2      1.30      Deerfield  Massachusetts        2032
# 7  7  for_sale  4.0     1      0.11       Herkimer       New York        1404
# 8  8  for_sale  4.0     4     11.00        Campton  New Hampshire        3051
# 9  9  for_sale  3.0     1      4.60       Griswold    Connecticut        1422
#
#      price         timestamp
# 0  1799000  03-02-2022 17:44
# 1   284900  06-08-2022 03:33
# ...

# %%
df.tail(20)
# Out:
#              n    status  bed  bath  acre_lot             city          state  \
# 677122  677122  for_sale  2.0     2      0.08        Lyndhurst     New Jersey
# 677123  677123  for_sale  3.0     1      0.06    Broad Channel       New York
# 677124  677124  for_sale  2.0     2     13.35  Saint Johnsbury        Vermont
# 677125  677125  for_sale  2.0     1      1.93   Jeffersonville       New York
# 677126  677126  for_sale  4.0     3      0.85   Preston Hollow       New York
# 677127  677127  for_sale  2.0     2      0.14         Helmetta     New Jersey
# 677128  677128  for_sale  6.0     3      0.11           Boston  Massachusetts
# 677129  677129  for_sale  3.0     2      0.33         Vineland     New Jersey
# 677130  677130  for_sale  4.0     1      0.40         Dixfield          Maine
# 677131  677131  for_sale  3.0     1      0.18          Trenton     New Jersey
# 677132  677132  for_sale  4.0     3      0.46       Rocky Hill    Connecticut
# ...

# %%
df.dtypes
# Out:
# n               int64
# status         object
# bed           float64
# bath            int64
# acre_lot      float64
# city           object
# state          object
# house_size      int64
# price           int64
# timestamp      object
# dtype: object

# %%
df.describe()
# Out:
#                    n            bed           bath       acre_lot  \
# count  677142.000000  677140.000000  677142.000000  677142.000000
# mean   338570.500000       3.788719       2.668381      35.493180
# std    195474.202327       2.045733       2.033259    1318.966235
# min         0.000000       1.000000       1.000000       0.000000
# 25%    169285.250000       3.000000       2.000000       0.120000
# 50%    338570.500000       3.000000       2.000000       0.290000
# 75%    507855.750000       4.000000       3.000000       1.000000
# max    677141.000000      99.000000     198.000000  100000.000000
#
#          house_size         price
# count  6.771420e+05  6.771420e+05
# mean   2.396576e+03  7.418888e+05
# std    3.853333e+03  1.547229e+06
# min    1.220000e+02  1.000000e+00
# 25%    1.352000e+03  2.499000e+05
# 50%    1.894000e+03  4.290000e+05
# 75%    2.717000e+03  7.490000e+05
# max    1.450112e+06  1.690000e+08

# %%
df['price']
# Out:
# 0         1799000
# 1          284900
# 2          815000
# 3         5985000
# 4          975000
#            ...
# 677137     839900
# 677138    1499000
# 677139     185000
# 677140     479000
# 677141    1199999
# Name: price, Length: 677142, dtype: int64

# %%
df[df['price']>950000]
# Out:
#              n    status  bed  bath  acre_lot           city          state  \
# 0            0  for_sale  8.0     4      0.06       Brooklyn       New York
# 3            3  for_sale  6.0     8      4.00     New Canaan    Connecticut
# 4            4  for_sale  8.0     3      0.02          Bronx       New York
# 14          14  for_sale  1.0     2      0.33  New York City       New York
# 15          15  for_sale  4.0     5      0.32         Woburn  Massachusetts
# ...        ...       ...  ...   ...       ...            ...            ...
# 677121  677121  for_sale  4.0     4      0.25        Waltham  Massachusetts
# 677128  677128  for_sale  6.0     3      0.11         Boston  Massachusetts
# 677133  677133  for_sale  4.0     3      0.02         Boston  Massachusetts
# 677138  677138  for_sale  4.0     3     33.00       Woodbury    Connecticut
# 677141  677141  for_sale  4.0     3      0.14         Elmont       New York
#
#         house_size    price         timestamp
# ...

# %%
df.sort_values(by='state',ascending=False)
# Out:
#              n    status  bed  bath  acre_lot           city          state  \
# 223021  223021  for_sale  3.0     3      0.29           Cody        Wyoming
# 648553  648553  for_sale  3.0     3      0.29           Cody        Wyoming
# 637344  637344  for_sale  3.0     3      0.29           Cody        Wyoming
# 343762  343762  for_sale  4.0     2      0.17        Wyoming  West Virginia
# 518288  518288  for_sale  4.0     2      0.17        Wyoming  West Virginia
# ...        ...       ...  ...   ...       ...            ...            ...
# 611532  611532  for_sale  3.0     2      0.84      Waterford    Connecticut
# 473006  473006  for_sale  3.0     2      0.52  South Windsor    Connecticut
# 76300    76300  for_sale  3.0     1      0.62         Granby    Connecticut
# 611529  611529  for_sale  3.0     2      4.83         Canaan    Connecticut
# 89688    89688  for_sale  4.0     3      0.42    New Milford    Connecticut
#
#         house_size   price         timestamp
# ...

# %%
df.sort_values(by=['state','city'],ascending=True)
# Out:
#              n    status  bed  bath  acre_lot     city          state  \
# 27996    27996  for_sale  3.0     2      0.80  Andover    Connecticut
# 59465    59465  for_sale  3.0     3     16.08  Andover    Connecticut
# 82361    82361  for_sale  3.0     3      1.48  Andover    Connecticut
# 84983    84983  for_sale  3.0     2      1.08  Andover    Connecticut
# 100500  100500  for_sale  3.0     2      0.80  Andover    Connecticut
# ...        ...       ...  ...   ...       ...      ...            ...
# 651242  651242  for_sale  4.0     2      0.17  Wyoming  West Virginia
# 665768  665768  for_sale  4.0     2      0.17  Wyoming  West Virginia
# 223021  223021  for_sale  3.0     3      0.29     Cody        Wyoming
# 637344  637344  for_sale  3.0     3      0.29     Cody        Wyoming
# 648553  648553  for_sale  3.0     3      0.29     Cody        Wyoming
#
#         house_size   price         timestamp
# 27996          996  334000  16-12-2022 13:31
# ...

# %%
df['price_by_house_size']=df.price/df.house_size

# %%
df
# Out:
#              n    status  bed  bath  acre_lot           city          state  \
# 0            0  for_sale  8.0     4      0.06       Brooklyn       New York
# 1            1  for_sale  3.0     2      0.09  Campbell Hall       New York
# 2            2  for_sale  3.0     3      0.11      Hopkinton  Massachusetts
# 3            3  for_sale  6.0     8      4.00     New Canaan    Connecticut
# 4            4  for_sale  8.0     3      0.02          Bronx       New York
# ...        ...       ...  ...   ...       ...            ...            ...
# 677137  677137  for_sale  2.0     2     20.00      Cazenovia       New York
# 677138  677138  for_sale  4.0     3     33.00       Woodbury    Connecticut
# 677139  677139  for_sale  3.0     1      0.21      Millville     New Jersey
# 677140  677140  for_sale  3.0     3      1.80          Keene  New Hampshire
# 677141  677141  for_sale  4.0     3      0.14         Elmont       New York
#
# ...

# %%
df.drop(columns=['price_by_house_size','n','status'],inplace=True)

# %%
df
# Out:
#         bed  bath  acre_lot           city          state  house_size  \
# 0       8.0     4      0.06       Brooklyn       New York        3198
# 1       3.0     2      0.09  Campbell Hall       New York        1482
# 2       3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3       6.0     8      4.00     New Canaan    Connecticut        9385
# 4       8.0     3      0.02          Bronx       New York        2565
# ...     ...   ...       ...            ...            ...         ...
# 677137  2.0     2     20.00      Cazenovia       New York        1900
# 677138  4.0     3     33.00       Woodbury    Connecticut        2416
# 677139  3.0     1      0.21      Millville     New Jersey        1074
# 677140  3.0     3      1.80          Keene  New Hampshire        2175
# 677141  4.0     3      0.14         Elmont       New York        2816
#
#           price         timestamp
# 0       1799000  03-02-2022 17:44
# 1        284900  06-08-2022 03:33
# ...

# %%
df.loc[677137]['city']
# Out:
# 'Cazenovia'

# %%
df.iloc[677137]['city']
# Out:
# 'Cazenovia'

# %%
df.iloc[2:10]['city']
# Out:
# 2     Hopkinton
# 3    New Canaan
# 4         Bronx
# 5        Granby
# 6     Deerfield
# 7      Herkimer
# 8       Campton
# 9      Griswold
# Name: city, dtype: object

# %%
df[['price','house_size']]
# Out:
#           price  house_size
# 0       1799000        3198
# 1        284900        1482
# 2        815000        2556
# 3       5985000        9385
# 4        975000        2565
# ...         ...         ...
# 677137   839900        1900
# 677138  1499000        2416
# 677139   185000        1074
# 677140   479000        2175
# 677141  1199999        2816
#
# [677142 rows x 2 columns]

# %%
df[(df['price']>950000) & (df['city']=='New York')]
# Out:
#         bed  bath  acre_lot      city     state  house_size     price  \
# 968     9.0     4      0.05  New York  New York        5304   3950000
# 1317    5.0     7      0.04  New York  New York        3850   1725000
# 1539    9.0     4      0.05  New York  New York        5304   3950000
# 2032    9.0     4      0.05  New York  New York        5304   3950000
# 2218    8.0     8      0.05  New York  New York       11371  32500000
# ...     ...   ...       ...       ...       ...         ...       ...
# 665412  9.0     4      0.05  New York  New York        5304   3950000
# 668209  8.0     4      0.05  New York  New York        2898   2388000
# 669334  6.0     7      0.03  New York  New York        4030   4200000
# 672026  6.0     7      0.03  New York  New York        4030   4200000
# 676000  2.0     2      0.17  New York  New York        1429   3100000
#
#                timestamp
# 968     23-06-2022 05:13
# 1317    08-02-2022 19:26
# 1539    30-09-2022 05:31
# ...

# %%
df.isnull()
# Out:
#           bed   bath  acre_lot   city  state  house_size  price  timestamp
# 0       False  False     False  False  False       False  False      False
# 1       False  False     False  False  False       False  False      False
# 2       False  False     False  False  False       False  False      False
# 3       False  False     False  False  False       False  False      False
# 4       False  False     False  False  False       False  False      False
# ...       ...    ...       ...    ...    ...         ...    ...        ...
# 677137  False  False     False  False  False       False  False      False
# 677138  False  False     False  False  False       False  False      False
# 677139  False  False     False  False  False       False  False      False
# 677140  False  False     False  False  False       False  False      False
# 677141  False  False     False  False  False       False  False      False
#
# [677142 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# bed           2
# bath          0
# acre_lot      0
# city          1
# state         0
# house_size    0
# price         0
# timestamp     0
# dtype: int64

# %%
df['bed'].fillna(df['bed'].mean())
# Out:
# 0         8.0
# 1         3.0
# 2         3.0
# 3         6.0
# 4         8.0
#          ...
# 677137    2.0
# 677138    4.0
# 677139    3.0
# 677140    3.0
# 677141    4.0
# Name: bed, Length: 677142, dtype: float64

# %%
df['bed']=df['bed'].fillna(df['bed'].mean())

# %%
df.isnull().sum()
# Out:
# bed           0
# bath          0
# acre_lot      0
# city          1
# state         0
# house_size    0
# price         0
# timestamp     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# bed           0
# bath          0
# acre_lot      0
# city          0
# state         0
# house_size    0
# price         0
# timestamp     0
# dtype: int64

# %%
data_2 = {'bed': [9.0, 3.0],
          'bath': [4, 4],
          'acre_lot': [0.36, 0.15],
          'city': ['New York', 'New York'],
          'state': ['New York', 'New York'],
          'house_size': [5501, 5344],
          'price': [3730000, 3580000],
          'timestamp': ['2022-06-23 05:13', '2022-06-21 05:26']}

# %%
df_2=pd.DataFrame(data_2)
df_2
# Out:
#    bed  bath  acre_lot      city     state  house_size    price  \
# 0  9.0     4      0.36  New York  New York        5501  3730000
# 1  3.0     4      0.15  New York  New York        5344  3580000
#
#           timestamp
# 0  2022-06-23 05:13
# 1  2022-06-21 05:26

# %%
df
# Out:
#         bed  bath  acre_lot           city          state  house_size  \
# 0       8.0     4      0.06       Brooklyn       New York        3198
# 1       3.0     2      0.09  Campbell Hall       New York        1482
# 2       3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3       6.0     8      4.00     New Canaan    Connecticut        9385
# 4       8.0     3      0.02          Bronx       New York        2565
# ...     ...   ...       ...            ...            ...         ...
# 677137  2.0     2     20.00      Cazenovia       New York        1900
# 677138  4.0     3     33.00       Woodbury    Connecticut        2416
# 677139  3.0     1      0.21      Millville     New Jersey        1074
# 677140  3.0     3      1.80          Keene  New Hampshire        2175
# 677141  4.0     3      0.14         Elmont       New York        2816
#
#           price         timestamp
# 0       1799000  03-02-2022 17:44
# 1        284900  06-08-2022 03:33
# ...

# %%
pd.concat([df,df_2])
# Out:
#         bed  bath  acre_lot           city          state  house_size  \
# 0       8.0     4      0.06       Brooklyn       New York        3198
# 1       3.0     2      0.09  Campbell Hall       New York        1482
# 2       3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3       6.0     8      4.00     New Canaan    Connecticut        9385
# 4       8.0     3      0.02          Bronx       New York        2565
# ...     ...   ...       ...            ...            ...         ...
# 677139  3.0     1      0.21      Millville     New Jersey        1074
# 677140  3.0     3      1.80          Keene  New Hampshire        2175
# 677141  4.0     3      0.14         Elmont       New York        2816
# 0       9.0     4      0.36       New York       New York        5501
# 1       3.0     4      0.15       New York       New York        5344
#
#           price         timestamp
# 0       1799000  03-02-2022 17:44
# 1        284900  06-08-2022 03:33
# ...

# %%
df_3=pd.concat([df,df_2])

# %%
df_3
# Out:
#         bed  bath  acre_lot           city          state  house_size  \
# 0       8.0     4      0.06       Brooklyn       New York        3198
# 1       3.0     2      0.09  Campbell Hall       New York        1482
# 2       3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3       6.0     8      4.00     New Canaan    Connecticut        9385
# 4       8.0     3      0.02          Bronx       New York        2565
# ...     ...   ...       ...            ...            ...         ...
# 677139  3.0     1      0.21      Millville     New Jersey        1074
# 677140  3.0     3      1.80          Keene  New Hampshire        2175
# 677141  4.0     3      0.14         Elmont       New York        2816
# 0       9.0     4      0.36       New York       New York        5501
# 1       3.0     4      0.15       New York       New York        5344
#
#           price         timestamp
# 0       1799000  03-02-2022 17:44
# 1        284900  06-08-2022 03:33
# ...

# %%
df_3.dtypes
# Out:
# bed           float64
# bath            int64
# acre_lot      float64
# city           object
# state          object
# house_size      int64
# price           int64
# timestamp      object
# dtype: object

# %%
pd.to_datetime(df_3['timestamp'])
# Out:
# 0        2022-03-02 17:44:00
# 1        2022-06-08 03:33:00
# 2        2022-10-28 01:35:00
# 3        2022-07-29 13:27:00
# 4        2022-10-13 20:01:00
#                  ...
# 677139   2022-06-25 13:13:00
# 677140   2022-12-16 11:03:00
# 677141   2022-11-08 20:21:00
# 0        2022-06-23 05:13:00
# 1        2022-06-21 05:26:00
# Name: timestamp, Length: 677143, dtype: datetime64[ns]

# %%
df_3['timestamp']=pd.to_datetime(df_3['timestamp'])

# %%
df_3
# Out:
#         bed  bath  acre_lot           city          state  house_size  \
# 0       8.0     4      0.06       Brooklyn       New York        3198
# 1       3.0     2      0.09  Campbell Hall       New York        1482
# 2       3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3       6.0     8      4.00     New Canaan    Connecticut        9385
# 4       8.0     3      0.02          Bronx       New York        2565
# ...     ...   ...       ...            ...            ...         ...
# 677139  3.0     1      0.21      Millville     New Jersey        1074
# 677140  3.0     3      1.80          Keene  New Hampshire        2175
# 677141  4.0     3      0.14         Elmont       New York        2816
# 0       9.0     4      0.36       New York       New York        5501
# 1       3.0     4      0.15       New York       New York        5344
#
#           price           timestamp
# 0       1799000 2022-03-02 17:44:00
# 1        284900 2022-06-08 03:33:00
# ...

# %%
df_3.dtypes
# Out:
# bed                  float64
# bath                   int64
# acre_lot             float64
# city                  object
# state                 object
# house_size             int64
# price                  int64
# timestamp     datetime64[ns]
# dtype: object

# %%
df_3['year']=df_3['timestamp'].dt.year
df_3['month']=df_3['timestamp'].dt.month
df_3['day']=df_3['timestamp'].dt.day
df_3['hour']=df_3['timestamp'].dt.hour
df_3['minute']=df_3['timestamp'].dt.minute

# %%
df_3
# Out:
#         bed  bath  acre_lot           city          state  house_size  \
# 0       8.0     4      0.06       Brooklyn       New York        3198
# 1       3.0     2      0.09  Campbell Hall       New York        1482
# 2       3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3       6.0     8      4.00     New Canaan    Connecticut        9385
# 4       8.0     3      0.02          Bronx       New York        2565
# ...     ...   ...       ...            ...            ...         ...
# 677139  3.0     1      0.21      Millville     New Jersey        1074
# 677140  3.0     3      1.80          Keene  New Hampshire        2175
# 677141  4.0     3      0.14         Elmont       New York        2816
# 0       9.0     4      0.36       New York       New York        5501
# 1       3.0     4      0.15       New York       New York        5344
#
#           price           timestamp  year  month  day  hour  minute
# ...

# %%
df_3['second']=df_3['timestamp'].dt.second

# %%
df_3
# Out:
#         bed  bath  acre_lot           city          state  house_size  \
# 0       8.0     4      0.06       Brooklyn       New York        3198
# 1       3.0     2      0.09  Campbell Hall       New York        1482
# 2       3.0     3      0.11      Hopkinton  Massachusetts        2556
# 3       6.0     8      4.00     New Canaan    Connecticut        9385
# 4       8.0     3      0.02          Bronx       New York        2565
# ...     ...   ...       ...            ...            ...         ...
# 677139  3.0     1      0.21      Millville     New Jersey        1074
# 677140  3.0     3      1.80          Keene  New Hampshire        2175
# 677141  4.0     3      0.14         Elmont       New York        2816
# 0       9.0     4      0.36       New York       New York        5501
# 1       3.0     4      0.15       New York       New York        5344
#
#           price           timestamp  year  month  day  hour  minute  second
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jnoot'

# %%
os.chdir('F:\Data Science\Kaggle Data Sets')

# %%
df_3.to_csv('df_3.csv')
